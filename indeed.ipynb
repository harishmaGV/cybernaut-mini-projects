# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed"],
    search_term="python developer",
    location="Hyderabad, Telangana",
    results_wanted=50,
    hours_old=72, 
    country_indeed='India',  
    
    
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
    
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2024-10-18 18:05:56,047 - JobSpy - INFO - Indeed search page: 1
# 2024-10-18 18:05:57,395 - JobSpy - INFO - Indeed search page: 2
# 2024-10-18 18:05:57,962 - JobSpy - INFO - Indeed found no jobs on page: 2
# 2024-10-18 18:05:57,962 - JobSpy - INFO - Indeed finished scraping
# Found 43 jobs
#                  id    site  \
# 0  90ff47967afc4ccd  indeed
# 1  2bc8cfd79eb79b03  indeed
# 4  abd72a85f652465c  indeed
# 3  0244a50eaf21cbf1  indeed
# 5  f43045bbfe2f1d34  indeed
#
#                                              job_url  \
# 0  https://in.indeed.com/viewjob?jk=90ff47967afc4ccd
# 1  https://in.indeed.com/viewjob?jk=2bc8cfd79eb79b03
# 4  https://in.indeed.com/viewjob?jk=abd72a85f652465c
# 3  https://in.indeed.com/viewjob?jk=0244a50eaf21cbf1
# 5  https://in.indeed.com/viewjob?jk=f43045bbfe2f1d34
#
#                                       job_url_direct                 title  \
# 0  http://in.indeed.com/job/full-stack-developer-...  Full Stack Developer
# 1  https://careers.microsoft.com/us/en/job/177783...   Software Engineer 2
# 4  http://in.indeed.com/job/php-developer-abd72a8...         PHP Developer
# 3  https://careers.wipro.com/jobs/3112548/job?utm...             Developer
# 5    https://www.magnifyit.in/jobs/python-developer/      Python Developer
#
#                      company location  job_type date_posted salary_source  \
# 0  Cogsy Solutions Pvt. Ltd.   TS, IN  fulltime  2024-10-18          None
# 1                  Microsoft   TS, IN  fulltime  2024-10-18          None
# 4     Oakmont Magnus Global    TS, IN  fulltime  2024-10-18          None
# 3                      Wipro   TS, IN  fulltime  2024-10-17          None
# 5                 Magnify It   TS, IN  fulltime  2024-10-17          None
#
#    ...                                        company_url  \
# 0  ...  https://in.indeed.com/cmp/Cogsy-Solutions-Pvt....
# 1  ...                https://in.indeed.com/cmp/Microsoft
# 4  ...    https://in.indeed.com/cmp/Oakmont-Magnus-Global
# 3  ...                    https://in.indeed.com/cmp/Wipro
# 5  ...               https://in.indeed.com/cmp/Magnify-IT
#
#           company_url_direct  \
# 0                        NaN
# 1  http://www.microsoft.com/
# 4                        NaN
# 3       http://www.wipro.com
# 5                        NaN
#
#                                   company_addresses company_num_employees  \
# 0                                               NaN                   NaN
# 1  One Microsoft Way Redmond, Washington 98052-6399               10,000+
# 4                                               NaN                   NaN
# 3                                         Bengaluru               10,000+
# 5                                               NaN                   NaN
#
#         company_revenue                                company_description  \
# 0                   NaN                                                NaN
# 1  more than $10B (USD)  Our mission is to empower every person and eve...
# 4                   NaN                                                NaN
# 3     $5B to $10B (USD)
# 5                   NaN                                                NaN
#
#                                       logo_photo_url  \
# 0                                                NaN
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 4                                                NaN
# 3  https://d2q79iu7y748jz.cloudfront.net/s/_squar...
# 5                                                NaN
#
#                                     banner_photo_url       ceo_name  \
# 0                                                NaN            NaN
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_heade...  Satya Nadella
# 4                                                NaN            NaN
# 3  https://d2q79iu7y748jz.cloudfront.net/s/_heade...   Srini Pallia
# 5                                                NaN            NaN
#
#                                        ceo_photo_url
# 0                                                NaN
# 1  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...
# 4                                                NaN
# 3  https://d2q79iu7y748jz.cloudfront.net/s/_ceoph...
# 5                                                NaN
#
# [5 rows x 31 columns]
